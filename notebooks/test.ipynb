# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from proto.etl.config import SSHInfoEicu, DBInfoEicu
from proto.etl.utils import connect_to_db_via_ssh
conn = connect_to_db_via_ssh(SSHInfoEicu, DBInfoEicu)

# %%
query_schema = 'set search_path to eicu_crd;'
patientunitstayid = 2704494
query = query_schema + """
select *
from admissiondrug
where patientunitstayid = {}
order by drugoffset
""".format(patientunitstayid)

df = pd.read_sql_query(query, conn)
df.head()
# Out:
#    admissiondrugid  patientunitstayid  drugoffset  drugenteredoffset  \
# 0         13383113            2704494      -87132               2153
# 1         13383111            2704494      -87132               2153
# 2         13383112            2704494      -87132               2153
# 3         13383114            2704494      -87132               2153
# 4         13383116            2704494      -87132               2153
#
#              drugnotetype specialtytype       usertype rxincluded  \
# 0  Comprehensive Progress   eCM Primary  THC Physician       True
# 1  Comprehensive Progress   eCM Primary  THC Physician       True
# 2  Comprehensive Progress   eCM Primary  THC Physician       True
# 3  Comprehensive Progress   eCM Primary  THC Physician       True
# 4  Comprehensive Progress   eCM Primary  THC Physician       True
#
#   writtenineicu                                           drugname  \
# 0         False  HYDRALAZINE HCL                               ...
# 1         False  COREG                                         ...
# 2         False  EXEMESTANE                                    ...
# 3         False  IMDUR                                         ...
# 4         False  PROTONIX                                      ...
#
#    drugdosage drugunit drugadmitfrequency  drughiclseqno
# 0         0.0                                         89
# 1         0.0                                      13795
# 2         0.0                                      20803
# 3         0.0                                       6341
# 4         0.0                                      22008

# %%
query = query_schema + """
select 
  pt.hospitalid
  , count(pt.patientunitstayid) as number_of_patients
  , count(ad.patientunitstayid) as number_of_patients_with_admdrug
from patient pt
left join admissiondrug ad
  on pt.patientunitstayid = ad.patientunitstayid
group by pt.hospitalid
""".format(patientunitstayid)

df = pd.read_sql_query(query, con)
df['data completion'] = df['number_of_patients_with_admdrug'] / df['number_of_patients'] * 100.0
df.sort_values('number_of_patients_with_admdrug', ascending=False, inplace=True)
df.head(n=10)
# Out:
#      hospitalid  number_of_patients  number_of_patients_with_admdrug  \
# 54          420              342170                           341168
# 158         142               33887                            33003
# 12          382               29047                            28871
# 163         365               25941                            25735
# 72          281               25564                            25092
# 141         391               22992                            22840
# 6           394               23574                            22485
# 68          440               23644                            22343
# 100         283               20045                            19724
# 118         443               20072                            18666
#
#      data completion
# 54         99.707163
# 158        97.391330
# 12         99.394085
# 163        99.205890
# 72         98.153654
# 141        99.338900
# 6          95.380504
# 68         94.497547
# 100        98.398603
# 118        92.995217

# %%
query = query_schema + """
select *
from admissiondx
where patientunitstayid = {}
""".format(patientunitstayid)

df = pd.read_sql_query(query, con)
df.head()
# Out:
#    admissiondxid  patientunitstayid  admitdxenteredoffset  \
# 0        7981672            2704494                    20
# 1        7981671            2704494                    20
# 2        7981673            2704494                    20
#
#                                          admitdxpath       admitdxname  \
# 0  admission diagnosis|Non-operative Organ System...        Hematology
# 1  admission diagnosis|Was the patient admitted f...                No
# 2  admission diagnosis|All Diagnosis|Non-operativ...  Thrombocytopenia
#
#         admitdxtext
# 0        Hematology
# 1                No
# 2  Thrombocytopenia

# %%
for i, row in df.iterrows():
    print('Row {}'.format(i+1))
    for c in ['admitdxpath', 'admitdxname', 'admitdxtext']:
        print('  {}: {}'.format(c, row[c]))
# Out:
# Row 1
#   admitdxpath: admission diagnosis|Non-operative Organ Systems|Organ System|Hematology
#   admitdxname: Hematology
#   admitdxtext: Hematology
# Row 2
#   admitdxpath: admission diagnosis|Was the patient admitted from the O.R. or went to the O.R. within 4 hours of admission?|No
#   admitdxname: No
#   admitdxtext: No
# Row 3
#   admitdxpath: admission diagnosis|All Diagnosis|Non-operative|Diagnosis|Hematology|Thrombocytopenia
#   admitdxname: Thrombocytopenia
#   admitdxtext: Thrombocytopenia

# %%
query = query_schema + """
select *
from diagnosis
where patientunitstayid = {}
order by diagnosisoffset
""".format(patientunitstayid)

df = pd.read_sql_query(query, con)
df
# Out:
#     diagnosisid  patientunitstayid activeupondischarge  diagnosisoffset  \
# 0      32722297            2704494               False               48
# 1      31935854            2704494               False               48
# 2      33818792            2704494               False               48
# 3      32391279            2704494               False               48
# 4      33010439            2704494               False             2153
# 5      33098216            2704494               False             2153
# 6      32825172            2704494               False             2153
# 7      33368560            2704494               False             2153
# 8      33376417            2704494                True             2159
# 9      32981160            2704494                True             2159
# 10     33529588            2704494                True             2159
# 11     32465222            2704494                True             2159
#
#                                    diagnosisstring        icd9code  \
# 0     renal|disorder of kidney|acute renal failure    584.9, N17.9
# 1           oncology|chest tumors|breast CA|female  174.9, C50.919
# 2   cardiovascular|shock / hypotension|hypotension    458.9, I95.9
# 3         oncology|hematologic malignancy|leukemia
# 4     renal|disorder of kidney|acute renal failure    584.9, N17.9
# 5   cardiovascular|shock / hypotension|hypotension    458.9, I95.9
# 6           oncology|chest tumors|breast CA|female  174.9, C50.919
# 7         oncology|hematologic malignancy|leukemia
# 8   cardiovascular|shock / hypotension|hypotension    458.9, I95.9
# 9           oncology|chest tumors|breast CA|female  174.9, C50.919
# 10    renal|disorder of kidney|acute renal failure    584.9, N17.9
# 11        oncology|hematologic malignancy|leukemia
#
#    diagnosispriority
# 0              Major
# 1              Major
# 2            Primary
# 3              Major
# 4              Major
# 5            Primary
# 6              Major
# 7              Major
# 8            Primary
# 9              Major
# 10             Major
# 11             Major

# %%
icd9 = '250.'
query = query_schema + """
select diagnosisstring, icd9code
, count(distinct patientunitstayid) as n
from diagnosis
where icd9code like '%{}%'
group by diagnosisstring, icd9code
order by diagnosisstring, n desc
""".format(icd9)

df = pd.read_sql_query(query, con)
df
# Out:
#                                      diagnosisstring        icd9code     n
# 0                   endocrine|glucose metabolism|DKA   250.13, E10.1  5024
# 1  endocrine|glucose metabolism|DKA|with altered ...  250.33, E10.11   333
# 2  endocrine|glucose metabolism|diabetes mellitus...   250.00, E11.9   678
# 3  endocrine|glucose metabolism|diabetes mellitus...  250.02, E11.65   791
# 4  endocrine|glucose metabolism|diabetes mellitus...   250.01, E10.9    67
# 5  endocrine|glucose metabolism|diabetes mellitus...  250.03, E10.65   211
# 6  endocrine|glucose metabolism|hyperosmolar nonk...  250.23, E13.00   148
# 7  endocrine|glucose metabolism|hyperosmolar nonk...  250.22, E11.01     5

# %%
dx = 'endocrine|glucose metabolism'
query = query_schema + """
select diagnosisstring, icd9code
, count(distinct patientunitstayid) as n
from diagnosis
where diagnosisstring like '%{}%'
group by diagnosisstring, icd9code
order by diagnosisstring, n desc
""".format(dx)

df = pd.read_sql_query(query, con)
df
# Out:
#                                       diagnosisstring  \
# 0                    endocrine|glucose metabolism|DKA
# 1   endocrine|glucose metabolism|DKA|with altered ...
# 2      endocrine|glucose metabolism|diabetes mellitus
# 3   endocrine|glucose metabolism|diabetes mellitus...
# 4   endocrine|glucose metabolism|diabetes mellitus...
# 5   endocrine|glucose metabolism|diabetes mellitus...
# 6   endocrine|glucose metabolism|diabetes mellitus...
# 7   endocrine|glucose metabolism|diabetes mellitus...
# 8   endocrine|glucose metabolism|diabetes mellitus...
# 9          endocrine|glucose metabolism|hyperglycemia
# 10  endocrine|glucose metabolism|hyperglycemia|cor...
# 11  endocrine|glucose metabolism|hyperglycemia|due...
# 12  endocrine|glucose metabolism|hyperglycemia|str...
# 13  endocrine|glucose metabolism|hyperglycemia|sus...
# 14  endocrine|glucose metabolism|hyperosmolar nonk...
# 15  endocrine|glucose metabolism|hyperosmolar nonk...
# 16  endocrine|glucose metabolism|hyperosmolar nonk...
# 17          endocrine|glucose metabolism|hypoglycemia
# 18  endocrine|glucose metabolism|hypoglycemia|from...
# 19  endocrine|glucose metabolism|hypoglycemia|from...
# 20  endocrine|glucose metabolism|hypoglycemia|from...
# 21  endocrine|glucose metabolism|hypoglycemia|susp...
#
#                        icd9code      n
# 0                 250.13, E10.1   5024
# 1                250.33, E10.11    333
# 2                                14620
# 3                                  497
# 4                                 3263
# 5                 250.00, E11.9    678
# 6                250.02, E11.65    791
# 7                 250.01, E10.9     67
# 8                250.03, E10.65    211
# 9                  790.6, R73.9   5485
# 10                 790.6, R73.9    395
# 11                 790.6, R73.9     22
# 12                 790.6, R73.9   2483
# 13                                1363
# 14                                 289
# 15               250.23, E13.00    148
# 16               250.22, E11.01      5
# 17                 251.1, E16.2   1556
# 18  251.1, E932.3, E16.0, T38.3     82
# 19                 251.1, E16.1      4
# 20  251.1, E932.3, E16.0, T38.3     43
# 21                                  60

# %%
patientunitstayid = 242380
query = query_schema + """
select *
from infusiondrug
where patientunitstayid = {}
order by infusionoffset
""".format(patientunitstayid)

df = pd.read_sql_query(query, con)
df.head()
# Out:
#    infusiondrugid  patientunitstayid  infusionoffset                 drugname  \
# 0         2001050             242380              59  Nitroglycerin (mcg/min)
# 1         1953142             242380              59       Heparin (units/hr)
# 2         1973839             242380             239  Nitroglycerin (mcg/min)
# 3         1951808             242380             239       Heparin (units/hr)
# 4         1977744             242380             419  Nitroglycerin (mcg/min)
#
#   drugrate infusionrate drugamount volumeoffluid patientweight
# 0       10            3         50           250
# 1     1000           20      25000           500
# 2       20            6         50           250
# 3     1000           20      25000           500
# 4        0            0         50           250

# %%
query = query_schema + """
select labname, count(*) as n
from lab
group by labname
order by n desc
""".format(patientunitstayid)

lab = pd.read_sql_query(query, con)
print('{} total vlues for {} distinct labs.'.format(lab['n'].sum(), lab.shape[0]))
print('\nTop 25 labs by frequency:')
lab.head(25)
# Out:
# 39132531 total vlues for 158 distinct labs.
#
# Top 25 labs by frequency:
#              labname        n
# 0    bedside glucose  3175835
# 1          potassium  1493261
# 2             sodium  1393205
# 3            glucose  1319496
# 4                Hgb  1298708
# 5           chloride  1283839
# 6                Hct  1279704
# 7         creatinine  1277760
# 8                BUN  1270484
# 9            calcium  1226978
# 10       bicarbonate  1199866
# 11  platelets x 1000  1149488
# 12        WBC x 1000  1134952
# 13               RBC  1132361
# 14               MCV  1105350
# 15              MCHC  1104854
# 16               MCH  1059865
# 17               RDW  1048569
# 18         anion gap  1024278
# 19               MPV   770659
# 20         magnesium   648642
# 21           -lymphs   630836
# 22            -monos   625898
# 23              -eos   583568
# 24            -polys   559192
