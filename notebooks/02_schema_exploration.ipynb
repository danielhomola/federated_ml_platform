# %% [markdown]
# ## Exploring the schema
#
# In this notebook we systematically go through the tables' schemas and define the tables/columns which are relevant/useful for modelling and cohort building.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# establish connection to DB and define helper function for running queries

# %%
import pandas as pd
from proto.etl.config import SSHInfoEicu, DBInfoEicu
from proto.etl.utils import connect_to_db_via_ssh, run_eicu_query, get_column_completeness, load_schema_for_modelling

conn = connect_to_db_via_ssh(SSHInfoEicu, DBInfoEicu)
cursor = conn.cursor()
query_schema = 'set search_path to eicu_crd;'

# %% [markdown]
# ### Work out how many patient each hospital has, keep patients from top 5

# %%
query = """
    select hospitalid, count(patientunitstayid) as n
    from patient 
    group by hospitalid 
    order by n desc
"""

df_hospitals = run_eicu_query(query, conn)
df_hospitals.head()
# Out:
#    hospitalid     n
# 0          73  7059
# 1         167  6092
# 2         264  5237
# 3         420  4679
# 4         176  4328

# %%
# 30 hospitals (out of the 208) have half of the patients
df_hospitals.head(30).n.sum()

# for the basic cohort building we'll keep the top 5
top_hospitals = df_hospitals.hospitalid[:5].values

# %% [markdown]
# ### Execute all SQL sripts from the eicu-code repo
#
# There are a bunch of sql scripts that make pivotted tables with some basic features out of the original messy tables. These scripts were written by the authors of the eicu dataset.
#
# Run those in PyCharm, along with `setup/eicu_sql_scripts/top5hospitals/patient_top5hospitals.sql` which will create a view of the largest 5 hospitals' patients that we can use for the POC.

# %% [markdown]
# ### Extract schema for all tables

# %%
query = """
select table_name from information_schema.tables
where table_schema = 'eicu_crd'
"""
df_tables = run_eicu_query(query, conn)
df_tables
# Out:
#                        table_name
# 0                   admissiondrug
# 1                     admissiondx
# 2                         allergy
# 3                    apacheapsvar
# 4             apachepatientresult
# 5                   apachepredvar
# 6            careplancareprovider
# 7                     careplaneol
# 8                 careplangeneral
# 9                    careplangoal
# 10      careplaninfectiousdisease
# 11                      customlab
# 12                      diagnosis
# 13                       hospital
# 14                   infusiondrug
# 15                   intakeoutput
# 16                            lab
# 17                     medication
# 18                       microlab
# 19                           note
# 20                nurseassessment
# 21                      nursecare
# 22                  nursecharting
# 23                    pasthistory
# 24                        patient
# 25                   physicalexam
# 26                respiratorycare
# 27            respiratorycharting
# 28                      treatment
# 29                 vitalaperiodic
# 30                  vitalperiodic
# 31                     pivoted_bg
# 32               pivoted_infusion
# 33                    pivoted_lab
# 34                    pivoted_med
# 35                     pivoted_o2
# 36                  pivoted_score
# 37  pivoted_treatment_vasopressor
# 38                     pivoted_uo
# 39                  pivoted_vital
# 40            pivoted_vital_other

# %%
df_schemas = None
eicu_tables = df_tables.table_name.values
for table in eicu_tables:
    query = """
    select *
    from information_schema.columns
    where table_schema = 'eicu_crd'
    and table_name =  '%s'
    """ % table
    df_schema = run_eicu_query(query, conn)
    if df_schemas is None:
        df_schemas = df_schema
    else:
        df_schemas = pd.concat([df_schemas, df_schema], axis=0)
df_schemas = df_schemas.reset_index().drop('index', axis=1)
df_schemas.to_csv('../setup/eicu_schema.csv')

# %%
df_schemas.tail(25)
# Out:
#     table_catalog table_schema           table_name          column_name  \
# 485          eicu     eicu_crd        pivoted_vital       nibp_diastolic
# 486          eicu     eicu_crd        pivoted_vital            nibp_mean
# 487          eicu     eicu_crd        pivoted_vital          temperature
# 488          eicu     eicu_crd        pivoted_vital  temperaturelocation
# 489          eicu     eicu_crd        pivoted_vital         ibp_systolic
# 490          eicu     eicu_crd        pivoted_vital        ibp_diastolic
# 491          eicu     eicu_crd        pivoted_vital             ibp_mean
# 492          eicu     eicu_crd  pivoted_vital_other    patientunitstayid
# 493          eicu     eicu_crd  pivoted_vital_other          chartoffset
# 494          eicu     eicu_crd  pivoted_vital_other          entryoffset
# 495          eicu     eicu_crd  pivoted_vital_other           pasystolic
# 496          eicu     eicu_crd  pivoted_vital_other          padiastolic
# 497          eicu     eicu_crd  pivoted_vital_other               pamean
# 498          eicu     eicu_crd  pivoted_vital_other                   sv
# 499          eicu     eicu_crd  pivoted_vital_other                   co
# 500          eicu     eicu_crd  pivoted_vital_other                  svr
# 501          eicu     eicu_crd  pivoted_vital_other                  icp
# 502          eicu     eicu_crd  pivoted_vital_other                   ci
# 503          eicu     eicu_crd  pivoted_vital_other                 svri
# 504          eicu     eicu_crd  pivoted_vital_other                  cpp
# 505          eicu     eicu_crd  pivoted_vital_other                 svo2
# 506          eicu     eicu_crd  pivoted_vital_other                 paop
# 507          eicu     eicu_crd  pivoted_vital_other                  pvr
# 508          eicu     eicu_crd  pivoted_vital_other                 pvri
# 509          eicu     eicu_crd  pivoted_vital_other                  iap
#
#      ordinal_position column_default is_nullable data_type  \
# 485                 8           None         YES   numeric
# 486                 9           None         YES   numeric
# 487                10           None         YES   numeric
# 488                11           None         YES      text
# 489                12           None         YES   numeric
# 490                13           None         YES   numeric
# 491                14           None         YES   numeric
# 492                 1           None         YES   integer
# 493                 2           None         YES   integer
# 494                 3           None         YES   integer
# 495                 4           None         YES   numeric
# 496                 5           None         YES   numeric
# 497                 6           None         YES   numeric
# 498                 7           None         YES   numeric
# 499                 8           None         YES   numeric
# 500                 9           None         YES   numeric
# 501                10           None         YES   numeric
# 502                11           None         YES   numeric
# 503                12           None         YES   numeric
# 504                13           None         YES   numeric
# 505                14           None         YES   numeric
# 506                15           None         YES   numeric
# 507                16           None         YES   numeric
# 508                17           None         YES   numeric
# 509                18           None         YES   numeric
#
#     character_maximum_length character_octet_length  ...  is_identity  \
# 485                     None                    NaN  ...           NO
# 486                     None                    NaN  ...           NO
# 487                     None                    NaN  ...           NO
# 488                     None            1.07374e+09  ...           NO
# 489                     None                    NaN  ...           NO
# 490                     None                    NaN  ...           NO
# 491                     None                    NaN  ...           NO
# 492                     None                   None  ...           NO
# 493                     None                   None  ...           NO
# 494                     None                   None  ...           NO
# 495                     None                   None  ...           NO
# 496                     None                   None  ...           NO
# 497                     None                   None  ...           NO
# 498                     None                   None  ...           NO
# 499                     None                   None  ...           NO
# 500                     None                   None  ...           NO
# 501                     None                   None  ...           NO
# 502                     None                   None  ...           NO
# 503                     None                   None  ...           NO
# 504                     None                   None  ...           NO
# 505                     None                   None  ...           NO
# 506                     None                   None  ...           NO
# 507                     None                   None  ...           NO
# 508                     None                   None  ...           NO
# 509                     None                   None  ...           NO
#
#      identity_generation  identity_start identity_increment identity_maximum  \
# 485                 None            None               None             None
# 486                 None            None               None             None
# 487                 None            None               None             None
# 488                 None            None               None             None
# 489                 None            None               None             None
# 490                 None            None               None             None
# 491                 None            None               None             None
# 492                 None            None               None             None
# 493                 None            None               None             None
# 494                 None            None               None             None
# 495                 None            None               None             None
# 496                 None            None               None             None
# 497                 None            None               None             None
# 498                 None            None               None             None
# 499                 None            None               None             None
# 500                 None            None               None             None
# 501                 None            None               None             None
# 502                 None            None               None             None
# 503                 None            None               None             None
# 504                 None            None               None             None
# 505                 None            None               None             None
# 506                 None            None               None             None
# 507                 None            None               None             None
# 508                 None            None               None             None
# 509                 None            None               None             None
#
#     identity_minimum identity_cycle is_generated generation_expression  \
# 485             None             NO        NEVER                  None
# 486             None             NO        NEVER                  None
# 487             None             NO        NEVER                  None
# 488             None             NO        NEVER                  None
# 489             None             NO        NEVER                  None
# 490             None             NO        NEVER                  None
# 491             None             NO        NEVER                  None
# 492             None             NO        NEVER                  None
# 493             None             NO        NEVER                  None
# 494             None             NO        NEVER                  None
# 495             None             NO        NEVER                  None
# 496             None             NO        NEVER                  None
# 497             None             NO        NEVER                  None
# 498             None             NO        NEVER                  None
# 499             None             NO        NEVER                  None
# 500             None             NO        NEVER                  None
# 501             None             NO        NEVER                  None
# 502             None             NO        NEVER                  None
# 503             None             NO        NEVER                  None
# 504             None             NO        NEVER                  None
# 505             None             NO        NEVER                  None
# 506             None             NO        NEVER                  None
# 507             None             NO        NEVER                  None
# 508             None             NO        NEVER                  None
# 509             None             NO        NEVER                  None
#
#     is_updatable
# 485          YES
# 486          YES
# 487          YES
# 488          YES
# 489          YES
# 490          YES
# 491          YES
# 492          YES
# 493          YES
# 494          YES
# 495          YES
# 496          YES
# 497          YES
# 498          YES
# 499          YES
# 500          YES
# 501          YES
# 502          YES
# 503          YES
# 504          YES
# 505          YES
# 506          YES
# 507          YES
# 508          YES
# 509          YES
#
# [25 rows x 44 columns]

# %% [markdown]
# ### Define  important tables and columns
#
# - some tables are more relevant than others
# - also add completeness next to each column

# %%
tables_to_keep = [
    'admissiondx', 
    'apacheapsvar',
    'apachepatientresult', 
    'apachepredvar', 
    'diagnosis', 
    'hospital',
    'lab', 
    'medication', 
    'nurseassessment', 
    'nursecare', 
    'nursecharting',
    'pasthistory', 
    'patient', 
    'treatment',
    'vitalaperiodic',
    'vitalperiodic',
    'pivoted_bg',
    'pivoted_infusion',
    'pivoted_lab',
    'pivoted_med',
    'pivoted_o2',
    'pivoted_score',
    'pivoted_uo',
    'pivoted_vital',
    'pivoted_vital_other',
]

# %%
# restrict to tables that are useful for modelling, keep relevant cols
df_schema_final = df_schemas[df_schemas.table_name.isin(tables_to_keep)]
df_schema_final = df_schema_final.set_index('table_name')
df_schema_final = df_schema_final[
    [
        'column_name',
        'ordinal_position',
        'data_type',
        'udt_name'       
    ]
]

# %%
# calculate completeness info for each col
completeness = []
for table in df_schema_final.index.unique():
    table_cols = df_schemas.loc[table].column_name.values
    print(table, len(table_cols))
    completeness.append(get_column_completeness(table, table_cols, conn))
# Out:
# admissiondx 6
# apacheapsvar 26
# apachepatientresult 23
# apachepredvar 51
# diagnosis 7
# hospital 4
# lab 10
# medication 15
# nurseassessment 8
# nursecare 8
# nursecharting 8
# pasthistory 8
# patient 29
# treatment 5
# vitalaperiodic 13
# vitalperiodic 19
# pivoted_bg 10
# pivoted_infusion 10
# pivoted_lab 24
# pivoted_med 13
# pivoted_o2 6
# pivoted_uo 4
# pivoted_vital 14
# pivoted_vital_other 18

# %%
# add completeness info and save modelling_schema table
df_schema_final.insert(len(df_schema_final.columns), 'completeness', pd.concat(completeness).values/100.)
df_schema_final.to_csv('../setup/modelling_tables_schema.csv')

# %% [markdown]
# ### Modify the `modelling_tables_schema.csv` manually
#
# I went through all the columns to:
# - identify the time domain column
# - mark certain cols for deletion which were either non-relevant or not populated (relying on the `get_column_completeness`)
# - using this updated version, we now can create a naming object that holds all relevant table info for cohort building.
# - note this final updated version (`modelling_schema.csv`) was moved to the etl folder

# %% [markdown]
# #### Have a look at the final `modelling_schema.csv`

# %%
df_schema_final = load_schema_for_modelling()
df_schema_final.head(20)
# Out:
#                        column_name  ordinal_position          data_type  \
# table_name
# admissiondx          admissiondxid                 1            integer
# admissiondx      patientunitstayid                 2            integer
# admissiondx   admitdxenteredoffset                 3            integer
# admissiondx            admitdxpath                 4  character varying
# admissiondx            admitdxname                 5  character varying
# admissiondx            admitdxtext                 6  character varying
# apacheapsvar        apacheapsvarid                 1            integer
# apacheapsvar     patientunitstayid                 2            integer
# apacheapsvar             intubated                 3           smallint
# apacheapsvar                  vent                 4           smallint
# apacheapsvar              dialysis                 5           smallint
# apacheapsvar                  eyes                 6           smallint
# apacheapsvar                 motor                 7           smallint
# apacheapsvar                verbal                 8           smallint
# apacheapsvar                  meds                 9           smallint
# apacheapsvar                 urine                10   double precision
# apacheapsvar                   wbc                11   double precision
# apacheapsvar           temperature                12   double precision
# apacheapsvar       respiratoryrate                13   double precision
# apacheapsvar                sodium                14   double precision
#
#              udt_name  time_var  numeric  to_keep  data_table  completeness
# table_name
# admissiondx      int4         0        1        1           1           1.0
# admissiondx      int4         0        1        1           1           1.0
# admissiondx      int4         1        1        1           1           1.0
# admissiondx   varchar         0        0        1           1           1.0
# admissiondx   varchar         0        0        0           1           1.0
# admissiondx   varchar         0        0        0           1           1.0
# apacheapsvar     int4         0        1        1           1           1.0
# apacheapsvar     int4         0        1        1           1           1.0
# apacheapsvar     int2         0        1        1           1           1.0
# apacheapsvar     int2         0        1        1           1           1.0
# apacheapsvar     int2         0        1        1           1           1.0
# apacheapsvar     int2         0        1        1           1           1.0
# apacheapsvar     int2         0        1        1           1           1.0
# apacheapsvar     int2         0        1        1           1           1.0
# apacheapsvar     int2         0        1        1           1           1.0
# apacheapsvar   float8         0        1        1           1           1.0
# apacheapsvar   float8         0        1        1           1           1.0
# apacheapsvar   float8         0        1        1           1           1.0
# apacheapsvar   float8         0        1        1           1           1.0
# apacheapsvar   float8         0        1        1           1           1.0
